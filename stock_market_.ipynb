# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhravya56/ADA-LAB/blob/main/stock_market_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
mahindra = pd.read_csv('/content/MM.NS.csv', index_col='Date', parse_dates=['Date'])
mahindra.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-29  380.274994  387.450012  377.100006  386.575012  348.136383
# 2010-12-30  388.950012  391.350006  386.375000  388.049988  349.464630
# 2010-12-31  387.174988  392.450012  387.174988  389.100006  350.410309
# 2011-01-03  397.375000  400.850006  392.100006  393.774994  354.620422
# 2011-01-04  393.549988  396.000000  387.600006  390.625000  351.783691
#
#                Volume
# Date
# 2010-12-29  2068256.0
# 2010-12-30  4179444.0
# 2010-12-31   983276.0
# 2011-01-03  3674214.0
# 2011-01-04  3201716.0

# %%
reliance = pd.read_csv('/content/RILO - Copy.csv', index_col='Date', parse_dates=['Date'])
reliance.head()
# Out:
# <ipython-input-12-9ecff9aed8c7>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   reliance = pd.read_csv('/content/RILO - Copy.csv', index_col='Date', parse_dates=['Date'])
#               Symbol Series  Prev Close  Open Price  High Price  Low Price  \
# Date
# 2016-01-01  RELIANCE     EQ     1014.60     1009.80      1018.9    1008.20
# 2016-01-04  RELIANCE     EQ     1015.35     1005.00      1013.8     986.70
# 2016-01-05  RELIANCE     EQ      995.30     1000.30      1010.0     997.00
# 2016-01-06  RELIANCE     EQ     1005.15     1007.60      1038.4    1000.40
# 2016-01-07  RELIANCE     EQ     1032.20     1021.05      1028.0    1008.05
#
#             Last Price  Close Price  Average Price  Total Traded Quantity  \
# Date
# 2016-01-01      1013.6      1015.35        1015.52                1238135
# ...

# %%
tcs = pd.read_csv('/content/TCS.NS (1).csv', index_col='Date', parse_dates=['Date'])
tcs.head()
# Out:
#                   Open        High         Low       Close  Adj Close  \
# Date
# 2004-08-25  149.837494  149.837494  122.375000  123.493752  92.474930
# 2004-08-26  124.000000  124.625000  121.912498  122.375000  91.637184
# 2004-08-27  122.800003  122.800003  119.820000  120.332497  90.107712
# 2004-08-30  121.237503  123.750000  120.625000  123.345001  92.363548
# 2004-08-31  123.312500  123.750000  122.000000  123.512497  92.488968
#
#                 Volume
# Date
# 2004-08-25    136928.0
# 2004-08-26  40443200.0
# 2004-08-27  30646000.0
# 2004-08-30  24465208.0
# 2004-08-31  21194656.0

# %%
mahindra.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  3206.000000  3206.000000  3206.000000  3206.000000  3206.000000
# mean    693.084069   701.572793   683.632720   692.463739   660.062310
# std     295.116257   297.585094   291.932894   294.750412   302.032819
# min     263.399994   283.000000   245.399994   269.000000   259.467865
# 25%     477.637497   483.849998   471.081260   478.231240   440.874496
# 50%     637.975006   645.000000   630.000000   637.262512   598.175843
# 75%     779.850021   789.312515   768.587479   778.087524   751.894821
# max    1727.900024  1739.949951  1698.750000  1734.449951  1734.449951
#
#              Volume
# count  3.206000e+03
# mean   3.131513e+06
# std    2.295081e+06
# min    0.000000e+00
# 25%    1.722194e+06
# 50%    2.469430e+06
# 75%    3.791154e+06
# max    3.298648e+07

# %%
tcs.head()
# Out:
#                   Open        High         Low       Close  Adj Close  \
# Date
# 2004-08-25  149.837494  149.837494  122.375000  123.493752  92.474930
# 2004-08-26  124.000000  124.625000  121.912498  122.375000  91.637184
# 2004-08-27  122.800003  122.800003  119.820000  120.332497  90.107712
# 2004-08-30  121.237503  123.750000  120.625000  123.345001  92.363548
# 2004-08-31  123.312500  123.750000  122.000000  123.512497  92.488968
#
#                 Volume
# Date
# 2004-08-25    136928.0
# 2004-08-26  40443200.0
# 2004-08-27  30646000.0
# 2004-08-30  24465208.0
# 2004-08-31  21194656.0

# %%
reliance.describe()
# Out:
#         Prev Close   Open Price   High Price    Low Price   Last Price  \
# count  1324.000000  1324.000000  1324.000000  1324.000000  1324.000000
# mean   1311.043807  1313.436254  1328.644864  1297.260876  1312.213935
# std     377.738596   379.462103   384.037322   372.970908   378.085826
# min     780.900000   791.750000   793.400000   779.100000   781.200000
# 25%    1012.837500  1014.000000  1023.725000  1003.425000  1012.862500
# 50%    1230.075000  1231.750000  1244.300000  1214.175000  1230.900000
# 75%    1486.362500  1481.000000  1506.837500  1464.287500  1487.625000
# max    2324.550000  2325.000000  2369.350000  2310.550000  2324.900000
#
#        Close Price  Average Price  Total Traded Quantity      Turnover  \
# count  1324.000000    1324.000000           1.324000e+03  1.324000e+03
# mean   1312.119864    1313.226805           8.873225e+06  1.283806e+10
# std     377.840674     378.449456           7.489692e+06  1.380620e+10
# ...

# %%
print(tcs.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4085 entries, 2004-08-25 to 2021-02-24
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       4070 non-null   float64
#  1   High       4070 non-null   float64
#  2   Low        4070 non-null   float64
#  3   Close      4070 non-null   float64
#  4   Adj Close  4070 non-null   float64
#  5   Volume     4070 non-null   float64
# dtypes: float64(6)
# memory usage: 223.4 KB
# None

# %%
print(mahindra.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3212 entries, 2010-12-29 to 2023-12-28
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       3206 non-null   float64
#  1   High       3206 non-null   float64
#  2   Low        3206 non-null   float64
#  3   Close      3206 non-null   float64
#  4   Adj Close  3206 non-null   float64
#  5   Volume     3206 non-null   float64
# dtypes: float64(6)
# memory usage: 175.7 KB
# None

# %%
print(reliance.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1324 entries, 2016-01-01 to 2021-05-06
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Symbol                  1324 non-null   object
#  1   Series                  1324 non-null   object
#  2   Prev Close              1324 non-null   float64
#  3   Open Price              1324 non-null   float64
#  4   High Price              1324 non-null   float64
#  5   Low Price               1324 non-null   float64
#  6   Last Price              1324 non-null   float64
#  7   Close Price             1324 non-null   float64
#  8   Average Price           1324 non-null   float64
#  9   Total Traded Quantity   1324 non-null   int64
#  10  Turnover                1324 non-null   float64
#  11  No. of Trades           1324 non-null   int64
#  12  Deliverable Qty         1324 non-null   int64
#  13  % Dly Qt to Traded Qty  1324 non-null   float64
# ...

# %%
mahindra = mahindra.dropna()

# %%
reliance = reliance.dropna()

# %%
tcs = tcs.dropna()

# %%
mahindra = mahindra.fillna(mahindra.mean())

# %%
reliance = reliance.fillna(reliance.mean())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1679             try:
# -> 1680                 x = x.astype(np.complex128)
#    1681             except (TypeError, ValueError):
#
# ValueError: complex() arg is a malformed string
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1682                 try:
# -> 1683                     x = x.astype(np.float64)
#    1684                 except ValueError as err:
#
# ValueError: could not convert string to float: '......
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
tcs = tcs.fillna(tcs.mean())

# %%
reliance = reliance.drop_duplicates()

# %%
tcs = tcs.drop_duplicates()

# %%
mahindra = mahindra.drop_duplicates()

# %%
plt.figure(figsize=(1000,600))

plt.plot(tcs['Close'], tcs['Volume'],label= 'tata')
# Out:
# Error in callback <function _draw_all_if_interactive at 0x791fe0120f70> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in _draw_all_if_interactive()
#     118 def _draw_all_if_interactive():
#     119     if matplotlib.is_interactive():
# --> 120         draw_all()
#     121
#     122
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     130         for manager in cls.get_all_fig_managers():
#     131             if force or manager.canvas.figure.stale:
# --> 132                 manager.canvas.draw_idle()
#     133
#     134
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2080         if not self._is_idle_drawing:
#    2081             with self._idle_draw_cntx():
# ...
